# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\dell 7410\internship\.conda\lib\site-packages (4.9.0.80)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.21.2 in c:\users\dell 7410\internship\.conda\lib\site-packages (from opencv-python) (1.26.4)

# %%
import cv2
print("OpenCV version:", cv2.__version__)
# Out:
# OpenCV version: 4.9.0

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\dell 7410\internship\.conda\lib\site-packages (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell 7410\internship\.conda\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell 7410\internship\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell 7410\internship\.conda\lib\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell 7410\internship\.conda\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\dell 7410\internship\.conda\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell 7410\internship\.conda\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\dell 7410\internship\.conda\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell 7410\internship\.conda\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell 7410\internship\.conda\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell 7410\internship\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
# Function to detect and draw rectangles around faces
def detect_faces(image_path):
    # Read the image
    img = cv2.imread(image_path)
    # Convert the image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Detect faces in the image
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

# %%
img = cv2.imread('C:\\Users\\Dell 7410\\Desktop\\project 1\\shutterstock_207143998.jpg')


gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

# %%
if len(faces) > 0:
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# %%
if len(faces) > 0:
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

    # Display the image with rectangles using Matplotlib
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.show()
else:
    print("No faces detected.")
